# %%
import pandas as pd
import numpy as np

arr = np.array([1,2,3,4,5])

print(pd.Series(arr))

# %%
import pandas as pd

dic = {
    "name": ["shubham", "soneir", "ABC","hello"],
    "marks": [10, 20, 30, 40],
}

df = pd.DataFrame(dic)
print(type(df))
print(df.iloc[:, 0])

# %%
import pandas as pd
import numpy as np

arr = np.array([1,2,3,4,5])

pdArr = pd.Series(arr)

print(pdArr.mean())
print(pdArr.std())

# %%
import pandas as pd
import numpy as np

arr = np.array([2,4,5,65,3,43,6,7])

pdArr = pd.Series(arr)

print(pdArr.sort_values())
