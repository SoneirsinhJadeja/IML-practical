# %%
import numpy as np

arr= np.arange(1, 15)

new_arr = np.split(arr, [2, 6])

print(arr)
print(new_arr)

# %%
import numpy as np

arr = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

# new_arr = np.stack((arr, arr2), axis=0)
new_arr = np.stack((arr, arr2)) # Both are same

print(arr)
print()

print(arr2)
print(new_arr)
